# %%
from ftplib import FTP_TLS
import gzip
import matplotlib.pyplot as plt
import numpy as np
import os
import csv

# %% [markdown]
# # FTP Config

# %%
host = "gdc.cddis.eosdis.nasa.gov"
port = 21  # passive mode
username = "anonymous"
password = ""

# %%
ftp = FTP_TLS()
ftp.connect(host, port)
ftp.login(username, password)
ftp.prot_p()
ftp.retrlines('LIST') # list files in server
# Out:
# lrwxrwxrwx    1 ftp      ftp             8 Sep 06  2022 GSAC -> pub/GSAC
# lrwxrwxrwx    1 ftp      ftp             9 Sep 06  2022 doris -> pub/doris
# lrwxrwxrwx    1 ftp      ftp            11 Sep 06  2022 glonass -> pub/glonass
# lrwxrwxrwx    1 ftp      ftp             7 Sep 06  2022 gnss -> pub/gps
# lrwxrwxrwx    1 ftp      ftp             7 Sep 06  2022 gps -> pub/gps
# drwxrwxr-x   26 ftp      ftp          4096 Jan 01 00:16 highrate
# lrwxrwxrwx    1 ftp      ftp             8 Sep 06  2022 misc -> pub/misc
# lrwxrwxrwx    1 ftp      ftp            12 Sep 06  2022 products -> pub/products
# drwxrwxr-x   13 ftp      ftp          4096 Feb 21  2023 pub
# lrwxrwxrwx    1 ftp      ftp            11 Sep 06  2022 reports -> pub/reports
# lrwxrwxrwx    1 ftp      ftp             7 Sep 06  2022 slr -> pub/slr
# lrwxrwxrwx    1 ftp      ftp             8 Sep 06  2022 vlbi -> pub/vlbi
# '226 Directory send OK.'

# %% [markdown]
# # Navigate to IGS Products

# %% [markdown]
# ## Functions

# %%
def fetch_clks(week):
    try:
        base_dir = '/pub/gps/products'
        ftp.cwd(base_dir)
        
        week_folder = f"{week}"
        ftp.cwd(week_folder)
    
        # List all files in the directory
        
        files = []
        ftp.retrlines('NLST', files.append)

        clk_files = [file for file in files if file.endswith('.CLK.gz')] # CLK is case-sensitive
    
        data = []
        line_ct = 0


        for i, clk_file in enumerate(clk_files):
            local_filename = f'/tmp/{clk_file}'
            
            with open(local_filename, 'wb') as f:
                  ftp.retrbinary(f"RETR {clk_file}", f.write)

            if clk_file.endswith('.gz'):
                local_uncompressed = local_filename[:-3]
                with gzip.open(local_filename, 'rb') as gzipped_file, open(local_uncompressed, 'wb') as decompressed_file:
                     decompressed_file.write(gzipped_file.read())

            file_path = local_uncompressed 

            with open(file_path, 'r') as file:
                end_header = False
                for line in file:
                    if not end_header:
                        if 'END OF HEADER' in line:
                            end_header = True
                        continue

                    if line.startswith('AS'): 
                        columns = line.split()
                        if len(columns) >= 9:
                            clock_data_type = columns[0]
                            sv_name = columns[1]
                            epoch_year = int(columns[2])
                            epoch_month = int(columns[3])
                            epoch_day = int(columns[4])
                            epoch_hour = int(columns[5])
                            epoch_minute = int(columns[6])
                            epoch_second = float(columns[7])
                            num_data_value = int(columns[8])
                            clock_bias = float(columns[9].lower().replace('d', 'e'))
                            clock_bias_stddev = float(columns[10].lower().replace('d', 'e')) if len(columns) > 10 else np.nan
                            clock_rate = float(columns[11].lower().replace('d', 'e')) if len(columns) > 11 else np.nan
                            clock_rate_stddev = float(columns[12].lower().replace('d', 'e')) if len(columns) > 12 else np.nan
                            clock_acceleration = float(columns[13].lower().replace('d', 'e')) if len(columns) > 13 else np.nan
                            clock_acceleration_stddev = float(columns[14].lower().replace('d', 'e')) if len(columns) > 14 else np.nan
                            
                            if sv_name.startswith('G'):
                                row = {
                                    'Clock Data Type': clock_data_type,
                                    'SV Name': sv_name,
                                    'Epoch Year': epoch_year,
                                    'Epoch Month': epoch_month,
                                    'Epoch Day': epoch_day,
                                    'Epoch Hour': epoch_hour,
                                    'Epoch Minute': epoch_minute,
                                    'Epoch Second': epoch_second,
                                    'Number of Data Values to Follow': num_data_value,
                                    'Clock Bias (seconds)': clock_bias,
                                    'Clock Bias StdDev (seconds)': clock_bias_stddev,
                                    'Clock Rate (dimensionless)': clock_rate,
                                    'Clock Rate StdDev (dimensionless)': clock_rate_stddev,
                                    'Clock Acceleration (per second)': clock_acceleration,
                                    'Clock Acceleration StdDev (per second)': clock_acceleration_stddev,
                                    }
                                data.append(row)

            print(f"Done reading file {i + 1} out of {len(clk_files)}")
            
        indices = np.arange(1,len(data)+1)
        print(f"Data for GPS week {week} has been indexed.")
        
        sv_names = [entry['SV Name'] for entry in data]
        print(f"SV Names for GPS week {week} have been saved.")
        
        epoch_years = [entry['Epoch Year'] for entry in data]
        print(f"Epoch Years for GPS week {week} have been saved.")
        
        epoch_months = [entry['Epoch Month'] for entry in data]
        print(f"Epoch Months for GPS week {week} have been saved.")
        
        epoch_days = [entry['Epoch Day'] for entry in data]
        print(f"Epoch Days for GPS week {week} have been saved.")
        
        epoch_hours = [entry['Epoch Hour'] for entry in data]
        print(f"Epoch Hours for GPS week {week} have been saved.")
        
        epoch_minutes = [entry['Epoch Minute'] for entry in data]
        print(f"Epoch Minutes for GPS week {week} have been saved.")
        
        epoch_seconds = [entry['Epoch Second'] for entry in data]
        print(f"Epoch Seconds for GPS week {week} have been saved.")
        
        clock_biases = [entry['Clock Bias (seconds)'] for entry in data]
        print(f"Clock biases (seconds) for GPS week {week} have been saved.")
        
        csv_filename = f"gps_{week}.csv"
        with open(csv_filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                header = ['Index', 'SV Name', 'Epoch Year', 'Epoch Month', 'Epoch Day', 'Epoch Hour', 'Epoch Minute', 'Epoch Second', 'Clock Bias (seconds)']
                csvwriter.writerow(header)
                for i in range(len(data)):
                    csvwriter.writerow([indices[i], sv_names[i], epoch_years[i], epoch_months[i], epoch_days[i], epoch_hours[i], epoch_minutes[i], epoch_seconds[i], clock_biases[i]])
        print(f"CSV file for GPS week {week} has been created.")

        np.savez(f'gps_{week}.npz', satellite=sv_names, clock_bias=clock_biases)
        print(f"npz file for GPS week {week} has been created.")

        print(f"Data collection for GPS week {week} has been completed.")
            
        # Remove the downloaded files
        # os.remove(local_file)
        # os.remove(local_file[:-3])
                    
    except Exception as e:
        print(f"Error fetching data for week {week}: {e}")

# %% [markdown]
# ## Get CLK Files

# %%
# %%time 
fetch_clks(2309)
# Out:
# Done reading file 1 out of 695
# Done reading file 2 out of 695
# Done reading file 3 out of 695
# Done reading file 4 out of 695
# Done reading file 5 out of 695
# Done reading file 6 out of 695
# Done reading file 7 out of 695
# Done reading file 8 out of 695
# Done reading file 9 out of 695
# Done reading file 10 out of 695
# Done reading file 11 out of 695
# Done reading file 12 out of 695
# Done reading file 13 out of 695
# Done reading file 14 out of 695
# Done reading file 15 out of 695
# Done reading file 16 out of 695
# Done reading file 17 out of 695
# Done reading file 18 out of 695
# Done reading file 19 out of 695
# Done reading file 20 out of 695
# Done reading file 21 out of 695
# Done reading file 22 out of 695
# Done reading file 23 out of 695
# Done reading file 24 out of 695
# Done reading file 25 out of 695
# Done reading file 26 out of 695
# Done reading file 27 out of 695
# Done reading file 28 out of 695
# Done reading file 29 out of 695
# Done reading file 30 out of 695
# Done reading file 31 out of 695
# Done reading file 32 out of 695
# Done reading file 33 out of 695
# Done reading file 34 out of 695
# Done reading file 35 out of 695
# Done reading file 36 out of 695
# Done reading file 37 out of 695
# Done reading file 38 out of 695
# Done reading file 39 out of 695
# Done reading file 40 out of 695
# Done reading file 41 out of 695
# Done reading file 42 out of 695
# Done reading file 43 out of 695
# Done reading file 44 out of 695
# Done reading file 45 out of 695
# Done reading file 46 out of 695
# Done reading file 47 out of 695
# Done reading file 48 out of 695
# Done reading file 49 out of 695
# Done reading file 50 out of 695
# Done reading file 51 out of 695
# Done reading file 52 out of 695
# Done reading file 53 out of 695
# Done reading file 54 out of 695
# Done reading file 55 out of 695
# Done reading file 56 out of 695
# Done reading file 57 out of 695
# Done reading file 58 out of 695
# Done reading file 59 out of 695
# Done reading file 60 out of 695
# Done reading file 61 out of 695
# Done reading file 62 out of 695
# Done reading file 63 out of 695
# Done reading file 64 out of 695
# Done reading file 65 out of 695
# Done reading file 66 out of 695
# Done reading file 67 out of 695
# Done reading file 68 out of 695
# Done reading file 69 out of 695
# Done reading file 70 out of 695
# Done reading file 71 out of 695
# Done reading file 72 out of 695
# Done reading file 73 out of 695
# Done reading file 74 out of 695
# Done reading file 75 out of 695
# Done reading file 76 out of 695
# Done reading file 77 out of 695
# Done reading file 78 out of 695
# Done reading file 79 out of 695
# Done reading file 80 out of 695
# Done reading file 81 out of 695
# Done reading file 82 out of 695
# Done reading file 83 out of 695
# Done reading file 84 out of 695
# Done reading file 85 out of 695
# Done reading file 86 out of 695
# Done reading file 87 out of 695
# Done reading file 88 out of 695
# Done reading file 89 out of 695
# Done reading file 90 out of 695
# Done reading file 91 out of 695
# Done reading file 92 out of 695
# Done reading file 93 out of 695
# Done reading file 94 out of 695
# Done reading file 95 out of 695
# Done reading file 96 out of 695
# Done reading file 97 out of 695
# Done reading file 98 out of 695
# Done reading file 99 out of 695
# Done reading file 100 out of 695
# Done reading file 101 out of 695
# Done reading file 102 out of 695
# Done reading file 103 out of 695
# Done reading file 104 out of 695
# Done reading file 105 out of 695
# Done reading file 106 out of 695
# Done reading file 107 out of 695
# Done reading file 108 out of 695
# Done reading file 109 out of 695
# Done reading file 110 out of 695
# Done reading file 111 out of 695
# Done reading file 112 out of 695
# Done reading file 113 out of 695
# Done reading file 114 out of 695
# Done reading file 115 out of 695
# Done reading file 116 out of 695
# Done reading file 117 out of 695
# Done reading file 118 out of 695
# Done reading file 119 out of 695
# Done reading file 120 out of 695
# Done reading file 121 out of 695
# Done reading file 122 out of 695
# Done reading file 123 out of 695
# Done reading file 124 out of 695
# Done reading file 125 out of 695
# Done reading file 126 out of 695
# Done reading file 127 out of 695
# Done reading file 128 out of 695
# Done reading file 129 out of 695
# Done reading file 130 out of 695
# Done reading file 131 out of 695
# Done reading file 132 out of 695
# Done reading file 133 out of 695
# Done reading file 134 out of 695
# Done reading file 135 out of 695
# Done reading file 136 out of 695
# Done reading file 137 out of 695
# Done reading file 138 out of 695
# Done reading file 139 out of 695
# Done reading file 140 out of 695
# Done reading file 141 out of 695
# Done reading file 142 out of 695
# Done reading file 143 out of 695
# Done reading file 144 out of 695
# Done reading file 145 out of 695
# Done reading file 146 out of 695
# Done reading file 147 out of 695
# Done reading file 148 out of 695
# Done reading file 149 out of 695
# Done reading file 150 out of 695
# Done reading file 151 out of 695
# Done reading file 152 out of 695
# Done reading file 153 out of 695
# Done reading file 154 out of 695
# Done reading file 155 out of 695
# Done reading file 156 out of 695
# Done reading file 157 out of 695
# Done reading file 158 out of 695
# Done reading file 159 out of 695
# Done reading file 160 out of 695
# Done reading file 161 out of 695
# Done reading file 162 out of 695
# Done reading file 163 out of 695
# Done reading file 164 out of 695
# Done reading file 165 out of 695
# Done reading file 166 out of 695
# Done reading file 167 out of 695
# Done reading file 168 out of 695
# Done reading file 169 out of 695
# Done reading file 170 out of 695
# Done reading file 171 out of 695
# Done reading file 172 out of 695
# Done reading file 173 out of 695
# Done reading file 174 out of 695
# Done reading file 175 out of 695
# Done reading file 176 out of 695
# Done reading file 177 out of 695
# Done reading file 178 out of 695
# Done reading file 179 out of 695
# Done reading file 180 out of 695
# Done reading file 181 out of 695
# Done reading file 182 out of 695
# Done reading file 183 out of 695
# Done reading file 184 out of 695
# Done reading file 185 out of 695
# Done reading file 186 out of 695
# Done reading file 187 out of 695
# Done reading file 188 out of 695
# Done reading file 189 out of 695
# Done reading file 190 out of 695
# Done reading file 191 out of 695
# Done reading file 192 out of 695
# Done reading file 193 out of 695
# Done reading file 194 out of 695
# Done reading file 195 out of 695
# Done reading file 196 out of 695
# Done reading file 197 out of 695
# Done reading file 198 out of 695
# Done reading file 199 out of 695
# Done reading file 200 out of 695
# Done reading file 201 out of 695
# Done reading file 202 out of 695
# Done reading file 203 out of 695
# Done reading file 204 out of 695
# Done reading file 205 out of 695
# Done reading file 206 out of 695
# Done reading file 207 out of 695
# Done reading file 208 out of 695
# Done reading file 209 out of 695
# Done reading file 210 out of 695
# Done reading file 211 out of 695
# Done reading file 212 out of 695
# Done reading file 213 out of 695
# Done reading file 214 out of 695
# Done reading file 215 out of 695
# Done reading file 216 out of 695
# Done reading file 217 out of 695
# Done reading file 218 out of 695
# Done reading file 219 out of 695
# Done reading file 220 out of 695
# Done reading file 221 out of 695
# Done reading file 222 out of 695
# Done reading file 223 out of 695
# Done reading file 224 out of 695
# Done reading file 225 out of 695
# Done reading file 226 out of 695
# Done reading file 227 out of 695
# Done reading file 228 out of 695
# Done reading file 229 out of 695
# Done reading file 230 out of 695
# Done reading file 231 out of 695
# Done reading file 232 out of 695
# Done reading file 233 out of 695
# Done reading file 234 out of 695
# Done reading file 235 out of 695
# Done reading file 236 out of 695
# Done reading file 237 out of 695
# Done reading file 238 out of 695
# Done reading file 239 out of 695
# Done reading file 240 out of 695
# Done reading file 241 out of 695
# Done reading file 242 out of 695
# Done reading file 243 out of 695
# Done reading file 244 out of 695
# Done reading file 245 out of 695
# Done reading file 246 out of 695
# Done reading file 247 out of 695
# Done reading file 248 out of 695
# Done reading file 249 out of 695
# Done reading file 250 out of 695
# Done reading file 251 out of 695
# Done reading file 252 out of 695
# Done reading file 253 out of 695
# Done reading file 254 out of 695
# Done reading file 255 out of 695
# Done reading file 256 out of 695
# Done reading file 257 out of 695
# Done reading file 258 out of 695
# Done reading file 259 out of 695
# Done reading file 260 out of 695
# Done reading file 261 out of 695
# Done reading file 262 out of 695
# Done reading file 263 out of 695
# Done reading file 264 out of 695
# Done reading file 265 out of 695
# Done reading file 266 out of 695
# Done reading file 267 out of 695
# Done reading file 268 out of 695
# Done reading file 269 out of 695
# Done reading file 270 out of 695
# Done reading file 271 out of 695
# Done reading file 272 out of 695
# Done reading file 273 out of 695
# Done reading file 274 out of 695
# Done reading file 275 out of 695
# Done reading file 276 out of 695
# Done reading file 277 out of 695
# Done reading file 278 out of 695
# Done reading file 279 out of 695
# Done reading file 280 out of 695
# Done reading file 281 out of 695
# Done reading file 282 out of 695
# Done reading file 283 out of 695
# Done reading file 284 out of 695
# Done reading file 285 out of 695
# Done reading file 286 out of 695
# Done reading file 287 out of 695
# Done reading file 288 out of 695
# Done reading file 289 out of 695
# Done reading file 290 out of 695
# Done reading file 291 out of 695
# Done reading file 292 out of 695
# Done reading file 293 out of 695
# Done reading file 294 out of 695
# Done reading file 295 out of 695
# Done reading file 296 out of 695
# Done reading file 297 out of 695
# Done reading file 298 out of 695
# Done reading file 299 out of 695
# Done reading file 300 out of 695
# Done reading file 301 out of 695
# Done reading file 302 out of 695
# Done reading file 303 out of 695
# Done reading file 304 out of 695
# Done reading file 305 out of 695
# Done reading file 306 out of 695
# Done reading file 307 out of 695
# Done reading file 308 out of 695
# Done reading file 309 out of 695
# Done reading file 310 out of 695
# Done reading file 311 out of 695
# Done reading file 312 out of 695
# Done reading file 313 out of 695
# Done reading file 314 out of 695
# Done reading file 315 out of 695
# Done reading file 316 out of 695
# Done reading file 317 out of 695
# Done reading file 318 out of 695
# Done reading file 319 out of 695
# Done reading file 320 out of 695
# Done reading file 321 out of 695
# Done reading file 322 out of 695
# Done reading file 323 out of 695
# Done reading file 324 out of 695
# Done reading file 325 out of 695
# Done reading file 326 out of 695
# Done reading file 327 out of 695
# Done reading file 328 out of 695
# Done reading file 329 out of 695
# Done reading file 330 out of 695
# Done reading file 331 out of 695
# Done reading file 332 out of 695
# Done reading file 333 out of 695
# Done reading file 334 out of 695
# Done reading file 335 out of 695
# Done reading file 336 out of 695
# Done reading file 337 out of 695
# Done reading file 338 out of 695
# Done reading file 339 out of 695
# Done reading file 340 out of 695
# Done reading file 341 out of 695
# Done reading file 342 out of 695
# Done reading file 343 out of 695
# Done reading file 344 out of 695
# Done reading file 345 out of 695
# Done reading file 346 out of 695
# Done reading file 347 out of 695
# Done reading file 348 out of 695
# Done reading file 349 out of 695
# Done reading file 350 out of 695
# Done reading file 351 out of 695
# Done reading file 352 out of 695
# Done reading file 353 out of 695
# Done reading file 354 out of 695
# Done reading file 355 out of 695
# Done reading file 356 out of 695
# Done reading file 357 out of 695
# Done reading file 358 out of 695
# Done reading file 359 out of 695
# Done reading file 360 out of 695
# Done reading file 361 out of 695
# Done reading file 362 out of 695
# Done reading file 363 out of 695
# Done reading file 364 out of 695
# Done reading file 365 out of 695
# Done reading file 366 out of 695
# Done reading file 367 out of 695
# Done reading file 368 out of 695
# Done reading file 369 out of 695
# Done reading file 370 out of 695
# Done reading file 371 out of 695
# Done reading file 372 out of 695
# Done reading file 373 out of 695
# Done reading file 374 out of 695
# Done reading file 375 out of 695
# Done reading file 376 out of 695
# Done reading file 377 out of 695
# Done reading file 378 out of 695
# Done reading file 379 out of 695
# Done reading file 380 out of 695
# Done reading file 381 out of 695
# Done reading file 382 out of 695
# Done reading file 383 out of 695
# Done reading file 384 out of 695
# Done reading file 385 out of 695
# Done reading file 386 out of 695
# Done reading file 387 out of 695
# Done reading file 388 out of 695
# Done reading file 389 out of 695
# Done reading file 390 out of 695
# Done reading file 391 out of 695
# Done reading file 392 out of 695
# Done reading file 393 out of 695
# Done reading file 394 out of 695
# Done reading file 395 out of 695
# Done reading file 396 out of 695
# Done reading file 397 out of 695
# Done reading file 398 out of 695
# Done reading file 399 out of 695
# Done reading file 400 out of 695
# Done reading file 401 out of 695
# Done reading file 402 out of 695
# Done reading file 403 out of 695
# Done reading file 404 out of 695
# Done reading file 405 out of 695
# Done reading file 406 out of 695
# Done reading file 407 out of 695
# Done reading file 408 out of 695
# Done reading file 409 out of 695
# Done reading file 410 out of 695
# Done reading file 411 out of 695
# Done reading file 412 out of 695
# Done reading file 413 out of 695
# Done reading file 414 out of 695
# Done reading file 415 out of 695
# Done reading file 416 out of 695
# Done reading file 417 out of 695
# Done reading file 418 out of 695
# Done reading file 419 out of 695
# Done reading file 420 out of 695
# Done reading file 421 out of 695
# Done reading file 422 out of 695
# Done reading file 423 out of 695
# Done reading file 424 out of 695
# Done reading file 425 out of 695
# Done reading file 426 out of 695
# Done reading file 427 out of 695
# Done reading file 428 out of 695
# Done reading file 429 out of 695
# Done reading file 430 out of 695
# Done reading file 431 out of 695
# Done reading file 432 out of 695
# Done reading file 433 out of 695
# Done reading file 434 out of 695
# Done reading file 435 out of 695
# Done reading file 436 out of 695
# Done reading file 437 out of 695
# Done reading file 438 out of 695
# Done reading file 439 out of 695
# Done reading file 440 out of 695
# Done reading file 441 out of 695
# Done reading file 442 out of 695
# Done reading file 443 out of 695
# Done reading file 444 out of 695
# Done reading file 445 out of 695
# Done reading file 446 out of 695
# Done reading file 447 out of 695
# Done reading file 448 out of 695
# Done reading file 449 out of 695
# Done reading file 450 out of 695
# Done reading file 451 out of 695
# Done reading file 452 out of 695
# Done reading file 453 out of 695
# Done reading file 454 out of 695
# Done reading file 455 out of 695
# Done reading file 456 out of 695
# Done reading file 457 out of 695
# Done reading file 458 out of 695
# Done reading file 459 out of 695
# Done reading file 460 out of 695
# Done reading file 461 out of 695
# Done reading file 462 out of 695
# Done reading file 463 out of 695
# Done reading file 464 out of 695
# Done reading file 465 out of 695
# Done reading file 466 out of 695
# Done reading file 467 out of 695
# Done reading file 468 out of 695
# Done reading file 469 out of 695
# Done reading file 470 out of 695
# Done reading file 471 out of 695
# Done reading file 472 out of 695
# Done reading file 473 out of 695
# Done reading file 474 out of 695
# Done reading file 475 out of 695
# Done reading file 476 out of 695
# Done reading file 477 out of 695
# Done reading file 478 out of 695
# Done reading file 479 out of 695
# Done reading file 480 out of 695
# Done reading file 481 out of 695
# Done reading file 482 out of 695
# Done reading file 483 out of 695
# Done reading file 484 out of 695
# Done reading file 485 out of 695
# Done reading file 486 out of 695
# Done reading file 487 out of 695
# Done reading file 488 out of 695
# Done reading file 489 out of 695
# Done reading file 490 out of 695
# Done reading file 491 out of 695
# Done reading file 492 out of 695
# Done reading file 493 out of 695
# Done reading file 494 out of 695
# Done reading file 495 out of 695
# Done reading file 496 out of 695
# Done reading file 497 out of 695
# Done reading file 498 out of 695
# Done reading file 499 out of 695
# Done reading file 500 out of 695
# Done reading file 501 out of 695
# Done reading file 502 out of 695
# Done reading file 503 out of 695
# Done reading file 504 out of 695
# Done reading file 505 out of 695
# Done reading file 506 out of 695
# Done reading file 507 out of 695
# Done reading file 508 out of 695
# Done reading file 509 out of 695
# Done reading file 510 out of 695
# Done reading file 511 out of 695
# Done reading file 512 out of 695
# Done reading file 513 out of 695
# Done reading file 514 out of 695
# Done reading file 515 out of 695
# Done reading file 516 out of 695
# Done reading file 517 out of 695
# Done reading file 518 out of 695
# Done reading file 519 out of 695
# Done reading file 520 out of 695
# Done reading file 521 out of 695
# Done reading file 522 out of 695
# Done reading file 523 out of 695
# Done reading file 524 out of 695
# Done reading file 525 out of 695
# Done reading file 526 out of 695
# Done reading file 527 out of 695
# Done reading file 528 out of 695
# Done reading file 529 out of 695
# Done reading file 530 out of 695
# Done reading file 531 out of 695
# Done reading file 532 out of 695
# Done reading file 533 out of 695
# Done reading file 534 out of 695
# Done reading file 535 out of 695
# Done reading file 536 out of 695
# Done reading file 537 out of 695
# Done reading file 538 out of 695
# Done reading file 539 out of 695
# Done reading file 540 out of 695
# Done reading file 541 out of 695
# Done reading file 542 out of 695
# Done reading file 543 out of 695
# Done reading file 544 out of 695
# Done reading file 545 out of 695
# Done reading file 546 out of 695
# Done reading file 547 out of 695
# Done reading file 548 out of 695
# Done reading file 549 out of 695
# Done reading file 550 out of 695
# Done reading file 551 out of 695
# Done reading file 552 out of 695
# Done reading file 553 out of 695
# Done reading file 554 out of 695
# Done reading file 555 out of 695
# Done reading file 556 out of 695
# Done reading file 557 out of 695
# Done reading file 558 out of 695
# Done reading file 559 out of 695
# Done reading file 560 out of 695
# Done reading file 561 out of 695
# Done reading file 562 out of 695
# Done reading file 563 out of 695
# Done reading file 564 out of 695
# Done reading file 565 out of 695
# Done reading file 566 out of 695
# Done reading file 567 out of 695
# Done reading file 568 out of 695
# Done reading file 569 out of 695
# Done reading file 570 out of 695
# Done reading file 571 out of 695
# Done reading file 572 out of 695
# Done reading file 573 out of 695
# Done reading file 574 out of 695
# Done reading file 575 out of 695
# Done reading file 576 out of 695
# Done reading file 577 out of 695
# Done reading file 578 out of 695
# Done reading file 579 out of 695
# Done reading file 580 out of 695
# Done reading file 581 out of 695
# Done reading file 582 out of 695
# Done reading file 583 out of 695
# Done reading file 584 out of 695
# Done reading file 585 out of 695
# Done reading file 586 out of 695
# Done reading file 587 out of 695
# Done reading file 588 out of 695
# Done reading file 589 out of 695
# Done reading file 590 out of 695
# Done reading file 591 out of 695
# Done reading file 592 out of 695
# Done reading file 593 out of 695
# Done reading file 594 out of 695
# Done reading file 595 out of 695
# Done reading file 596 out of 695
# Done reading file 597 out of 695
# Done reading file 598 out of 695
# Done reading file 599 out of 695
# Done reading file 600 out of 695
# Done reading file 601 out of 695
# Done reading file 602 out of 695
# Done reading file 603 out of 695
# Done reading file 604 out of 695
# Done reading file 605 out of 695
# Done reading file 606 out of 695
# Done reading file 607 out of 695
# Done reading file 608 out of 695
# Done reading file 609 out of 695
# Done reading file 610 out of 695
# Done reading file 611 out of 695
# Done reading file 612 out of 695
# Done reading file 613 out of 695
# Done reading file 614 out of 695
# Done reading file 615 out of 695
# Done reading file 616 out of 695
# Done reading file 617 out of 695
# Done reading file 618 out of 695
# Done reading file 619 out of 695
# Done reading file 620 out of 695
# Done reading file 621 out of 695
# Done reading file 622 out of 695
# Done reading file 623 out of 695
# Done reading file 624 out of 695
# Done reading file 625 out of 695
# Done reading file 626 out of 695
# Done reading file 627 out of 695
# Done reading file 628 out of 695
# Done reading file 629 out of 695
# Done reading file 630 out of 695
# Done reading file 631 out of 695
# Done reading file 632 out of 695
# Done reading file 633 out of 695
# Done reading file 634 out of 695
# Done reading file 635 out of 695
# Done reading file 636 out of 695
# Done reading file 637 out of 695
# Done reading file 638 out of 695
# Done reading file 639 out of 695
# Done reading file 640 out of 695
# Done reading file 641 out of 695
# Done reading file 642 out of 695
# Done reading file 643 out of 695
# Done reading file 644 out of 695
# Done reading file 645 out of 695
# Done reading file 646 out of 695
# Done reading file 647 out of 695
# Done reading file 648 out of 695
# Done reading file 649 out of 695
# Done reading file 650 out of 695
# Done reading file 651 out of 695
# Done reading file 652 out of 695
# Done reading file 653 out of 695
# Done reading file 654 out of 695
# Done reading file 655 out of 695
# Done reading file 656 out of 695
# Done reading file 657 out of 695
# Done reading file 658 out of 695
# Done reading file 659 out of 695
# Done reading file 660 out of 695
# Done reading file 661 out of 695
# Done reading file 662 out of 695
# Done reading file 663 out of 695
# Done reading file 664 out of 695
# Done reading file 665 out of 695
# Done reading file 666 out of 695
# Done reading file 667 out of 695
# Done reading file 668 out of 695
# Done reading file 669 out of 695
# Done reading file 670 out of 695
# Done reading file 671 out of 695
# Done reading file 672 out of 695
# Done reading file 673 out of 695
# Done reading file 674 out of 695
# Done reading file 675 out of 695
# Done reading file 676 out of 695
# Done reading file 677 out of 695
# Done reading file 678 out of 695
# Done reading file 679 out of 695
# Done reading file 680 out of 695
# Done reading file 681 out of 695
# Done reading file 682 out of 695
# Done reading file 683 out of 695
# Done reading file 684 out of 695
# Done reading file 685 out of 695
# Done reading file 686 out of 695
# Done reading file 687 out of 695
# Done reading file 688 out of 695
# Done reading file 689 out of 695
# Done reading file 690 out of 695
# Done reading file 691 out of 695
# Done reading file 692 out of 695
# Done reading file 693 out of 695
# Done reading file 694 out of 695
# Done reading file 695 out of 695
# Data for GPS week 2309 has been indexed.
# SV Names for GPS week 2309 have been saved.
# Epoch Years for GPS week 2309 have been saved.
# Epoch Months for GPS week 2309 have been saved.
# Epoch Days for GPS week 2309 have been saved.
# Epoch Hours for GPS week 2309 have been saved.
# Epoch Minutes for GPS week 2309 have been saved.
# Epoch Seconds for GPS week 2309 have been saved.
# Clock biases (seconds) for GPS week 2309 have been saved.
# CSV file for GPS week 2309 has been created.
# npz file for GPS week 2309 has been created.
# Data collection for GPS week 2309 has been completed.
# CPU times: user 4min 32s, sys: 2min 22s, total: 6min 55s
# Wall time: 40min 5s
